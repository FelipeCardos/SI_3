# %% [markdown]
# # Sistemas Inteligentes 2021/2022
#
# ## Mini-projeto 3: Aprendizagem Automática
#
# ## Relatório

# %% [markdown]
# ## Grupo: XX
#
# Número: xxx - Nome: xxx
#
# Número: xxx - Nome: xxx
#
# Número: xxx - Nome: xxx

# %% [markdown]
# ## 1. Processamento dos dados
#
# (remover) Descrever e comentar os passos na leitura e processamento dos dados

# %%
import pandas as pd
import numpy as np
import sklearn

df = pd.read_csv("test.csv")
df
col_idexs=[2,5,6,7,8,9]
col_names=np.array(df.columns)[col_idexs]
x=df.values[:,col_idexs]
y=df.values[:,5]
print(x)
print(y)
# Out:
# [['C' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'M' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'M' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'N' 'Y' 'Y' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['CL' 'F' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'Y' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'M' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'N' 'Y' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'Y' 'N']
#  ['D' 'F' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'Y' 'N']
#  ['D' 'F' 'Y' 'Y' 'Y' 'S']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'N' 'Y' 'Y' 'N']
#  ['C' 'M' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['D' 'M' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'N' 'Y' 'N' 'N']
#  ['D' 'F' 'N' 'Y' 'Y' 'S']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'M' 'N' 'N' 'N' 'N']
#  ['D' 'M' 'N' 'N' 'Y' 'Y']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'Y' 'Y' 'N' 'Y']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['D' 'F' 'N' 'Y' 'N' 'N']
#  ['CL' 'F' 'N' 'Y' 'Y' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'M' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['C' 'M' 'N' 'Y' 'N' 'N']
#  ['D' 'F' 'Y' 'Y' 'N' 'S']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['D' 'F' 'N' 'Y' 'Y' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'S']
#  ['C' 'F' 'N' 'N' 'Y' 'S']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'Y' 'N' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['D' 'F' 'N' 'N' 'Y' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['CL' 'F' 'N' 'Y' 'Y' 'N']
#  ['C' 'M' 'Unknown' 'Unknown' 'Unknown' 'S']
#  ['CL' 'F' 'N' 'Y' 'N' 'N']
#  ['D' 'F' 'N' 'Y' 'N' 'N']
#  ['CL' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'M' 'N' 'N' 'N' 'N']
#  ['C' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'Y' 'Y' 'Y' 'Y']
#  ['D' 'M' 'N' 'Y' 'N' 'N']
#  ['C' 'F' 'N' 'N' 'N' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']
#  ['D' 'F' 'Unknown' 'Unknown' 'Unknown' 'N']]
# ['F' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F'
#  'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M'
#  'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F'
#  'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F'
#  'F' 'F' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F']

# %% [markdown]
# ## 2. Ajustamento dos modelos
#
#
# ### 2.1. Teste de modelos e validação
#
# (remover) Enunciar as várias abordagens testadas para
# * Criar modelos
# * Validar modelos
# * Avaliar a qualidade dos modelos

# %% [markdown]
# ### 2.2. Seleção e apresentação do melhor modelo
#
# (remover) Apresentar todos os resultados para cada modelo obtido
#
# * Elencar o critério de selecção
# * Apresentar a árvore (se aplicável)
# * Discutir os resultados

# %% [markdown]
# ## 3. Validação do modelo final ajustado com um conjunto de validação independente
#
# (remover) O ficheiro `test.csv` contém um conjunto de dados não usado para treinar o modelo definido no ponto #2.
# * Preparar o data set
# * Correr o modelo selecionado como sendo o melhor nestes dados
# * Apresentar os resultados para as métricas de validação
# * Discutir os resultados alcançados confrontando os resultados com os obtidos anteriormente

# %% [markdown]
# ## 4. Competição
#
# (remover) Explicar os passos feitos para chegar à solução submetida na competição, tendo em conta:
#
# * A escolha dos parâmetros usados pelos classificadores
# * A escolha de atributos mais relevantes para a aprendizagem dos modelos
