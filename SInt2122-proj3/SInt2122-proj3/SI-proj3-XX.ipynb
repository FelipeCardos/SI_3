# %% [markdown]
# # Sistemas Inteligentes 2021/2022
#
# ## Mini-projeto 3: Aprendizagem Automática
#
# ## Relatório

# %% [markdown]
# ## Grupo: XX
#
# Número: xxx - Nome: xxx
#
# Número: xxx - Nome: xxx
#
# Número: xxx - Nome: xxx

# %% [markdown]
# ## 1. Processamento dos dados
#
# (remover) Descrever e comentar os passos na leitura e processamento dos dados

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text

df = pd.read_csv("train.csv", sep="\t")

# %%
col_idexs=[2,3,5,6,7,8,9]
col_names=np.array(df.columns)[col_idexs]
x=df.values[:,col_idexs]
y=df.values[:,19]

df_x=df[col_names]
df_xDum = pd.get_dummies(df_x, columns=col_names)
col_names_dum=np.array(df_xDum.columns)

df_xDum

l= df_xDum.values
l

sk_dt = DecisionTreeClassifier(criterion="entropy")
sk_dt.fit(l, y)

preds = sk_dt.predict(l)
for i in range(df_xDum.shape[0]):
    print(f"Classe real: {y[i]}; Previsão: {preds[i]} ")
print("\nNúmero Total de más predições: ", sum(preds!=y))

tree = export_text(sk_dt, feature_names=list(col_names_dum))
print(tree)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\felip\OneDrive\Área de Trabalho\ULisboa\SegundoAno\Semestre_2\SI\SI_3\SInt2122-proj3\SInt2122-proj3\SI-proj3-XX.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/%C3%81rea%20de%20Trabalho/ULisboa/SegundoAno/Semestre_2/SI/SI_3/SInt2122-proj3/SInt2122-proj3/SI-proj3-XX.ipynb#ch0000003?line=0'>1</a> col_idexs=[2,3,5,6,7,8,9]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/%C3%81rea%20de%20Trabalho/ULisboa/SegundoAno/Semestre_2/SI/SI_3/SInt2122-proj3/SInt2122-proj3/SI-proj3-XX.ipynb#ch0000003?line=1'>2</a> col_names=np.array(df.columns)[col_idexs]
#       <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/%C3%81rea%20de%20Trabalho/ULisboa/SegundoAno/Semestre_2/SI/SI_3/SInt2122-proj3/SInt2122-proj3/SI-proj3-XX.ipynb#ch0000003?line=2'>3</a> x=df.values[:,col_idexs]
#       <a href='vscode-notebook-cell:/c%3A/Users/felip/OneDrive/%C3%81rea%20de%20Trabalho/ULisboa/SegundoAno/Semestre_2/SI/SI_3/SInt2122-proj3/SInt2122-proj3/SI-proj3-XX.ipynb#ch0000003?line=3'>4</a> y=df.values[:,19]
#
# IndexError: index 2 is out of bounds for axis 0 with size 1

# %% [markdown]
# ## 2. Ajustamento dos modelos
#
#
# ### 2.1. Teste de modelos e validação
#
# (remover) Enunciar as várias abordagens testadas para
# * Criar modelos
# * Validar modelos
# * Avaliar a qualidade dos modelos

# %% [markdown]
# ### 2.2. Seleção e apresentação do melhor modelo
#
# (remover) Apresentar todos os resultados para cada modelo obtido
#
# * Elencar o critério de selecção
# * Apresentar a árvore (se aplicável)
# * Discutir os resultados

# %% [markdown]
# ## 3. Validação do modelo final ajustado com um conjunto de validação independente
#
# (remover) O ficheiro `test.csv` contém um conjunto de dados não usado para treinar o modelo definido no ponto #2.
# * Preparar o data set
# * Correr o modelo selecionado como sendo o melhor nestes dados
# * Apresentar os resultados para as métricas de validação
# * Discutir os resultados alcançados confrontando os resultados com os obtidos anteriormente

# %% [markdown]
# ## 4. Competição
#
# (remover) Explicar os passos feitos para chegar à solução submetida na competição, tendo em conta:
#
# * A escolha dos parâmetros usados pelos classificadores
# * A escolha de atributos mais relevantes para a aprendizagem dos modelos
